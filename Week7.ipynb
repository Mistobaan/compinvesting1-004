# %% [markdown]
# # Module 1 - Example of Information Feeds
#
# ## What to look for ?
# - Historical data you can back test
# - Survivor bias free (no dead stock)
# - Ease of integration with your system
# - Low Latency
#
# - Thomson Reuters Machine Readable News ( Full Text Machine learning Search )
# - StarMine
#   - Daily feed each evening
#   - Updates include analysts' revisions
# - Insider Insights
#   - Daily feed each evening
#   - Derived from public filings
#   - Value added by assessing importance of buying or selling
#
# ## What is Techinical Analysis ?
# - TA uses historical price and volume data only to compute *indicators*
# - Inidicators are calculated from recent price and volume data to predict future price movements
# - Indicators are *heuristics*
#
# ### Why TA is Controversial
# - Many believe that is just _voodoo_ or _superstitions_
# - Depends on information in historical price and volume
# - Leverages
#   - Psychology of the investors
#   - Market Physics
#
# - Agnostic, evidence-based approach
# - I have assessed technical indicators in
#   - Back testing
#   - Big data analysis
# - Weak predictive power
# - Why might it work ?
# - Best use: Whan a stock's indicators are contrary to the market
#
# ## Definition of TA
# - "Identify a trend a reversal at a relatively early stage and ride on that trend until the weight of the evidence shows or proves that the trend has reversed"
# - _Assumption_: "People will continue to make the same mistakes they have made in the past"
#
# ## 3 Branches
# - Sentiment indicators
#   - Emotions of investors
# - Flow of Funds Indicators
#   - How much cash has been flowing in or "out"
#   - What is the capacity of the market to buy or sell
# - Market Structure indicators
#   - Most of the indicators
#
# ## Tucker view on TA Indicators
# - At the millisecond level the price movement is driven by market mechanics.
# - Longest term price movement are harder to predict
#
# ## Major Theme: Underlying value (opinion)
# - Assumption is that there is a true underlying value for the asset
# - Emotions and market structure cause price to deviate
# - If we can estimate the underlying value, we can find arbitrage opportunities
#
# ## Using with Machine Learning
# - We need to convert to standard units. -1.0 / +1.0
#
# # Bollinger Bands
# - Indicator should adapt to volatility of Stock's prices
# ## How to compute
# - Read in historical closing prices
# - mid = "rolling mean over look back period
# - std = rolling stdev over look back
# - upper = mid + std
# - lower = mid - std
#
# $Value = \frac{price - mid}{std}$
